# %% [markdown]
# # Análise México
#
# Neste notebook será feito a análise de serie temporal do México com a analise da série temporal de covid no México.

# %%
# !pip install pymannkendall
# Importando as blibiotecas
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pymannkendall as mk
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller,acf, pacf
from statsmodels.tsa.arima_model import ARIMA
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pymannkendall in /usr/local/lib/python3.8/dist-packages (1.4.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from pymannkendall) (1.7.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from pymannkendall) (1.21.6)

# %%
serie_mex = pd.read_csv('Séries Temporais México.csv')
serie_mex.drop('Unnamed: 0',axis=1,inplace=True)
serie_mex.head()
# Out:
#          Date  Confirmed  Recovered  Deaths   Ano
# 0  2020-01-22          0        0.0       0  2020
# 1  2020-01-23          0        0.0       0  2020
# 2  2020-01-24          0        0.0       0  2020
# 3  2020-01-25          0        0.0       0  2020
# 4  2020-01-26          0        0.0       0  2020

# %%
serie_mex.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 713 entries, 0 to 712
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       713 non-null    object
#  1   Confirmed  713 non-null    int64
#  2   Recovered  713 non-null    float64
#  3   Deaths     713 non-null    int64
#  4   Ano        713 non-null    int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 28.0+ KB

# %%
# Transformado a coluna date de object para datetime
serie_mex['Date'] = pd.to_datetime(serie_mex['Date'],format='%Y-%m-%d')

# %%
serie_mex['Mês'] = serie_mex['Date'].dt.month

# %%
# Colocando a coluna da data para indice
serie_mex.set_index('Date',inplace=True)
serie_mex.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 713 entries, 2020-01-22 to 2022-01-03
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Confirmed  713 non-null    int64
#  1   Recovered  713 non-null    float64
#  2   Deaths     713 non-null    int64
#  3   Ano        713 non-null    int64
#  4   Mês        713 non-null    int64
# dtypes: float64(1), int64(4)
# memory usage: 33.4 KB

# %%
serie_mex.head()
# Out:
#             Confirmed  Recovered  Deaths   Ano  Mês
# Date
# 2020-01-22          0        0.0       0  2020    1
# 2020-01-23          0        0.0       0  2020    1
# 2020-01-24          0        0.0       0  2020    1
# 2020-01-25          0        0.0       0  2020    1
# 2020-01-26          0        0.0       0  2020    1

# %% [markdown]
# ## Aplicando o teste aos  Casos Confirmados e Mortes

# %%
# Aplicando para casos confirmados
resultado_conf = mk.original_test(serie_mex['Confirmed'])

nomes = ['Tendência','Presença de tendência','p-valor','Estatística do teste',
         'Tau Kendall','Pontuação Kendall','Variância S','Declive','Intercepto']


for i,j in zip(nomes,resultado_conf):
  print(i,":",j)
# Out:
# Tendência : increasing
# Presença de tendência : True
# p-valor : 0.0
# Estatística do teste : 39.84631297004695
# Tau Kendall : 0.9972107096143845
# Pontuação Kendall : 253120.0
# Variância S : 40352756.666666664
# Declive : 6498.899167822468
# Intercepto : -757580.1037447988

# %%
# Aplicando para óbitos 
resultado_mortes = mk.original_test(serie_mex['Deaths'])

for i,j in zip(nomes,resultado_mortes):
  print(i,":",j)
# Out:
# Tendência : increasing
# Presença de tendência : True
# p-valor : 0.0
# Estatística do teste : 39.70929813803657
# Tau Kendall : 0.9935940873347306
# Pontuação Kendall : 252202.0
# Variância S : 40337519.333333336
# Declive : 509.04828159645234
# Intercepto : -45539.18824833704

# %%
decom_conf = seasonal_decompose(serie_mex['Confirmed'])

fig, (ax1,ax2,ax3, ax4) = plt.subplots(4,1, figsize=(15,8))
decom_conf.observed.plot(ax=ax1,title='Série Original')
decom_conf.trend.plot(ax=ax2,title='Tendência')
decom_conf.seasonal.plot(ax=ax3,title='Sazonalidade')
decom_conf.resid.plot(ax=ax4,title='Ruido')
plt.tight_layout()

# %%
decom_morte = seasonal_decompose(serie_mex['Deaths'])

fig, (ax1,ax2,ax3, ax4) = plt.subplots(4,1, figsize=(15,8))
decom_morte.observed.plot(ax=ax1,title='Série Original')
decom_morte.trend.plot(ax=ax2,title='Tendência')
decom_morte.seasonal.plot(ax=ax3,title='Sazonalidade')
decom_morte.resid.plot(ax=ax4,title='Ruido')
plt.tight_layout()

# %%
# Separação entre treino e teste
treino = serie_mex[(serie_mex['Ano']<=2021)&(serie_mex['Mês']<12)]
teste = serie_mex[(serie_mex['Ano']==2021)&(serie_mex['Mês'] == 12)]

# %%
adf_conf = adfuller(serie_mex['Confirmed'])

print('Dickey-Fuller Aumentado')
print('Teste Estatístico: {:.4f}'.format(adf_conf[0]))
print('Valor-p: {:.4f}'.format(adf_conf[1]))
print('Valores Críticos:')
for key, value in adf_conf[4].items():
	print('\t{}: {:.4f}'.format(key, value))
# Out:
# Dickey-Fuller Aumentado
# Teste Estatístico: 0.0145
# Valor-p: 0.9597
# Valores Críticos:
# 	1%: -3.4398
# 	5%: -2.8657
# 	10%: -2.5690

# %%
adf_mort = adfuller(serie_mex['Deaths'])

print('Dickey-Fuller Aumentado')
print('Teste Estatístico: {:.4f}'.format(adf_mort[0]))
print('Valor-p: {:.4f}'.format(adf_mort[1]))
print('Valores Críticos:')
for key, value in adf_mort[4].items():
	print('\t{}: {:.4f}'.format(key, value))
# Out:
# Dickey-Fuller Aumentado
# Teste Estatístico: -1.3063
# Valor-p: 0.6263
# Valores Críticos:
# 	1%: -3.4398
# 	5%: -2.8657
# 	10%: -2.5690

# %%
df_diff_co = serie_mex['Confirmed'].diff(1)
df_diff_mor = serie_mex['Deaths'].diff(1)

# %%
lag_acf_co = acf(df_diff_co.dropna(), nlags=20)
lag_pacf_co = pacf(df_diff_mor.dropna(), nlags=20)
# Out:
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/stattools.py:667: FutureWarning: fft=True will become the default after the release of the 0.12 release of statsmodels. To suppress this warning, explicitly set fft=False.
#   warnings.warn(

# %%
plt.figure(figsize=(12,6))
plt.plot(lag_acf_co)
plt.axhline(y=-1.96 / (np.sqrt((len(df_diff_co) - 1))), linestyle='--', color='gray', linewidth=0.7)
plt.axhline(y=0, linestyle='--', color='gray', linewidth=0.7)
plt.axhline(y=1.96 / (np.sqrt((len(df_diff_co) - 1))), linestyle='--', color='gray', linewidth=0.7)
plt.title("Autocorrelação",fontsize=14)
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.plot(lag_pacf_co)
plt.axhline(y=-1.96 / (np.sqrt((len(lag_pacf_co ) - 1))), linestyle='--', color='gray', linewidth=0.7)
plt.axhline(y=0, linestyle='--', color='gray', linewidth=0.7)
plt.axhline(y=1.96 / (np.sqrt((len(lag_pacf_co ) - 1))), linestyle='--', color='gray', linewidth=0.7)
plt.title("Autocorrelação Parcial")
plt.show()

# %%
model = ARIMA(treino['Deaths'], order=(3,1,1))
result_AR = model.fit(disp = -1)
# Out:
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/base/tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/base/tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'

# %%
fc, se, conf = result_AR .forecast(31, alpha=0.05)

# %%
mape = np.mean(np.abs(fc - teste['Deaths'].values)/np.abs(teste['Deaths'].values))
mae = np.mean(np.abs(fc - teste['Deaths'].values)) 
rmse = np.mean((fc - teste['Deaths'])**2)**.5
print(mape)
print(mae)
print(rmse)
# Out:
# 0.003459136325611663
# 1031.7902202822227
# 1368.0032035244428

# %%
plt.figure(figsize=(12,6))
plt.title('Comparação da Predição Com os Valores Reais', fontsize=14)
plt.plot(teste.index,fc,label='Valor Predito')
plt.plot(teste.index,teste['Deaths'].values,label='Real')
plt.legend()
